# %%
from pathlib import Path
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
import requests
import json

# %%
# Team/Key dictionary
team_dict = {
    'Buffalo Bills': 'BUF',
 'Philadelphia Eagles': 'PHI',
 'Kansas City Chiefs': 'KC',
 'Tampa Bay Buccaneers': 'TB',
 'Minnesota Vikings': 'MIN',
 'San Francisco 49ers': 'SF',
 'Los Angeles Chargers': 'LAC',
 'Green Bay Packers': 'GB',
 'Baltimore Ravens': 'BAL',
 'Dallas Cowboys': 'DAL',
 'Los Angeles Rams': 'LAR',
 'Cincinnati Bengals': 'CIN',
 'Indianapolis Colts': 'IND',
 'New England Patriots': 'NE',
 'Tennessee Titans': 'TEN',
 'New York Giants': 'NYG',
 'Miami Dolphins': 'MIA',
 'Denver Broncos': 'DEN',
 'Las Vegas Raiders': 'LV',
 'New Orleans Saints': 'NO',
 'Jacksonville Jaguars': 'JAX',
 'New York Jets': 'NYJ',
 'Cleveland Browns': 'CLE',
 'Arizona Cardinals': 'ARI',
 'Atlanta Falcons': 'ATL',
 'Pittsburgh Steelers': 'PIT',
 'Seattle Seahawks': 'SEA',
 'Detroit Lions': 'DET',
 'Washington Commanders': 'WAS',
 'Chicago Bears': 'CHI',
 'Houston Texans': 'HOU',
 'Carolina Panthers': 'CAR'}

# %%
# Read in Football Outsiders
fo = pd.read_csv(Path('../data/fb_outsiders.csv'),
                index_col='Team')

fo = fo[['SB Win']]
fo['SB Win'] = fo['SB Win'].str.rstrip('%').astype(float) / 100.0
fo.head()
# Out:
#       SB Win
# Team
# BUF    0.321
# PHI    0.202
# KC     0.085
# DAL    0.081
# BAL    0.066

# %%
# Load environment 
load_dotenv('../api.env')
api_key = os.getenv('THE_ODDS_API_KEY')

# %%
# Form request string
sport = 'americanfootball_nfl_super_bowl_winner'
regions = 'us'

req_str = f'https://api.the-odds-api.com/v4/sports/{sport}/odds/?apiKey={api_key}&regions={regions}'

# %%
# Make API request
result = requests.get(req_str).json()

# %%
result_saved = result

result
# Out:
# [{'id': 'eb5274457814f2cc586fc6f7bb4f5640',
#   'has_outrights': True,
#   'sport_key': 'americanfootball_nfl_super_bowl_winner',
#   'sport_title': 'NFL Super Bowl Winner',
#   'commence_time': '2023-02-12T23:30:00Z',
#   'home_team': None,
#   'away_team': None,
#   'bookmakers': [{'key': 'betfair',
#     'title': 'Betfair',
#     'last_update': '2022-10-26T16:44:08Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.8},
#        {'name': 'Philadelphia Eagles', 'price': 7.2},
#        {'name': 'Kansas City Chiefs', 'price': 7.8},
#        {'name': 'Tampa Bay Buccaneers', 'price': 19.5},
#        {'name': 'Minnesota Vikings', 'price': 20.0},
#        {'name': 'Baltimore Ravens', 'price': 20.0},
#        {'name': 'Dallas Cowboys', 'price': 20.0},
#        {'name': 'San Francisco 49ers', 'price': 23.0},
#        {'name': 'Cincinnati Bengals', 'price': 24.0},
#        {'name': 'Los Angeles Rams', 'price': 38.0},
#        {'name': 'Green Bay Packers', 'price': 40.0},
#        {'name': 'Los Angeles Chargers', 'price': 42.0},
#        {'name': 'Miami Dolphins', 'price': 44.0},
#        {'name': 'New York Giants', 'price': 48.0},
#        {'name': 'Tennessee Titans', 'price': 60.0},
#        {'name': 'Las Vegas Raiders', 'price': 65.0},
#        {'name': 'New York Jets', 'price': 75.0},
#        {'name': 'Arizona Cardinals', 'price': 90.0},
#        {'name': 'Seattle Seahawks', 'price': 95.0},
#        {'name': 'Indianapolis Colts', 'price': 100.0},
#        {'name': 'New Orleans Saints', 'price': 100.0},
#        {'name': 'New England Patriots', 'price': 110.0},
#        {'name': 'Jacksonville Jaguars', 'price': 140.0},
#        {'name': 'Cleveland Browns', 'price': 150.0},
#        {'name': 'Carolina Panthers', 'price': 150.0},
#        {'name': 'Atlanta Falcons', 'price': 160.0},
#        {'name': 'Houston Texans', 'price': 200.0},
#        {'name': 'Washington Commanders', 'price': 210.0},
#        {'name': 'Denver Broncos', 'price': 230.0},
#        {'name': 'Pittsburgh Steelers', 'price': 260.0},
#        {'name': 'Chicago Bears', 'price': 300.0},
#        {'name': 'Detroit Lions', 'price': 520.0}]},
#      {'key': 'outrights_lay',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.85},
#        {'name': 'Philadelphia Eagles', 'price': 7.6},
#        {'name': 'Kansas City Chiefs', 'price': 8.0},
#        {'name': 'Minnesota Vikings', 'price': 22.0},
#        {'name': 'Baltimore Ravens', 'price': 22.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 22.0},
#        {'name': 'Dallas Cowboys', 'price': 22.0},
#        {'name': 'San Francisco 49ers', 'price': 24.0},
#        {'name': 'Cincinnati Bengals', 'price': 27.0},
#        {'name': 'Los Angeles Rams', 'price': 40.0},
#        {'name': 'Miami Dolphins', 'price': 48.0},
#        {'name': 'Los Angeles Chargers', 'price': 48.0},
#        {'name': 'New York Giants', 'price': 55.0},
#        {'name': 'Green Bay Packers', 'price': 60.0},
#        {'name': 'Tennessee Titans', 'price': 70.0},
#        {'name': 'Las Vegas Raiders', 'price': 75.0},
#        {'name': 'New York Jets', 'price': 85.0},
#        {'name': 'Arizona Cardinals', 'price': 150.0},
#        {'name': 'Indianapolis Colts', 'price': 250.0},
#        {'name': 'Seattle Seahawks', 'price': 270.0},
#        {'name': 'Atlanta Falcons', 'price': 270.0},
#        {'name': 'New England Patriots', 'price': 390.0},
#        {'name': 'New Orleans Saints', 'price': 600.0},
#        {'name': 'Carolina Panthers', 'price': 800.0},
#        {'name': 'Cleveland Browns', 'price': 980.0},
#        {'name': 'Denver Broncos', 'price': 990.0},
#        {'name': 'Pittsburgh Steelers', 'price': 1000.0},
#        {'name': 'Jacksonville Jaguars', 'price': 1000.0},
#        {'name': 'Detroit Lions', 'price': 1000.0},
#        {'name': 'Washington Commanders', 'price': 1000.0},
#        {'name': 'Chicago Bears', 'price': 1000.0}]}]},
#    {'key': 'williamhill_us',
#     'title': 'William Hill (US)',
#     'last_update': '2022-10-26T16:37:32Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.7},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 8.0},
#        {'name': 'San Francisco 49ers', 'price': 17.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Dallas Cowboys', 'price': 19.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#        {'name': 'Baltimore Ravens', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 23.0},
#        {'name': 'Los Angeles Chargers', 'price': 26.0},
#        {'name': 'Los Angeles Rams', 'price': 26.0},
#        {'name': 'Green Bay Packers', 'price': 29.0},
#        {'name': 'Miami Dolphins', 'price': 36.0},
#        {'name': 'Tennessee Titans', 'price': 41.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Las Vegas Raiders', 'price': 61.0},
#        {'name': 'New York Jets', 'price': 61.0},
#        {'name': 'New England Patriots', 'price': 81.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Seattle Seahawks', 'price': 101.0},
#        {'name': 'New Orleans Saints', 'price': 126.0},
#        {'name': 'Cleveland Browns', 'price': 126.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'Jacksonville Jaguars', 'price': 126.0},
#        {'name': 'Indianapolis Colts', 'price': 126.0},
#        {'name': 'Atlanta Falcons', 'price': 151.0},
#        {'name': 'Washington Commanders', 'price': 201.0},
#        {'name': 'Pittsburgh Steelers', 'price': 301.0},
#        {'name': 'Chicago Bears', 'price': 401.0},
#        {'name': 'Carolina Panthers', 'price': 501.0},
#        {'name': 'Detroit Lions', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 1001.0}]}]},
#    {'key': 'circasports',
#     'title': 'Circa Sports',
#     'last_update': '2022-10-26T16:43:52Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.5},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 6.5},
#        {'name': 'Dallas Cowboys', 'price': 17.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'San Francisco 49ers', 'price': 17.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 21.0},
#        {'name': 'Baltimore Ravens', 'price': 21.0},
#        {'name': 'Cincinnati Bengals', 'price': 21.0},
#        {'name': 'Green Bay Packers', 'price': 31.0},
#        {'name': 'Los Angeles Rams', 'price': 31.0},
#        {'name': 'Tennessee Titans', 'price': 41.0},
#        {'name': 'Miami Dolphins', 'price': 41.0},
#        {'name': 'Los Angeles Chargers', 'price': 51.0},
#        {'name': 'Las Vegas Raiders', 'price': 51.0},
#        {'name': 'New York Giants', 'price': 51.0},
#        {'name': 'Seattle Seahawks', 'price': 71.0},
#        {'name': 'New York Jets', 'price': 81.0},
#        {'name': 'New Orleans Saints', 'price': 91.0},
#        {'name': 'Atlanta Falcons', 'price': 91.0},
#        {'name': 'Arizona Cardinals', 'price': 91.0},
#        {'name': 'New England Patriots', 'price': 101.0},
#        {'name': 'Indianapolis Colts', 'price': 126.0},
#        {'name': 'Cleveland Browns', 'price': 151.0},
#        {'name': 'Chicago Bears', 'price': 151.0},
#        {'name': 'Jacksonville Jaguars', 'price': 251.0},
#        {'name': 'Denver Broncos', 'price': 301.0},
#        {'name': 'Pittsburgh Steelers', 'price': 451.0},
#        {'name': 'Carolina Panthers', 'price': 501.0},
#        {'name': 'Detroit Lions', 'price': 701.0},
#        {'name': 'Houston Texans', 'price': 1001.0}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2022-10-26T16:36:49Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.7},
#        {'name': 'Philadelphia Eagles', 'price': 6.5},
#        {'name': 'Kansas City Chiefs', 'price': 7.5},
#        {'name': 'San Francisco 49ers', 'price': 16.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 17.0},
#        {'name': 'Baltimore Ravens', 'price': 18.0},
#        {'name': 'Dallas Cowboys', 'price': 18.0},
#        {'name': 'Cincinnati Bengals', 'price': 22.0},
#        {'name': 'Los Angeles Rams', 'price': 25.0},
#        {'name': 'Los Angeles Chargers', 'price': 30.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'Green Bay Packers', 'price': 34.0},
#        {'name': 'New York Giants', 'price': 42.0},
#        {'name': 'Tennessee Titans', 'price': 48.0},
#        {'name': 'Las Vegas Raiders', 'price': 66.0},
#        {'name': 'Arizona Cardinals', 'price': 76.0},
#        {'name': 'New England Patriots', 'price': 76.0},
#        {'name': 'New York Jets', 'price': 76.0},
#        {'name': 'Cleveland Browns', 'price': 101.0},
#        {'name': 'New Orleans Saints', 'price': 101.0},
#        {'name': 'Seattle Seahawks', 'price': 101.0},
#        {'name': 'Indianapolis Colts', 'price': 101.0},
#        {'name': 'Jacksonville Jaguars', 'price': 111.0},
#        {'name': 'Denver Broncos', 'price': 121.0},
#        {'name': 'Atlanta Falcons', 'price': 171.0},
#        {'name': 'Washington Commanders', 'price': 211.0},
#        {'name': 'Chicago Bears', 'price': 251.0},
#        {'name': 'Detroit Lions', 'price': 261.0},
#        {'name': 'Carolina Panthers', 'price': 551.0},
#        {'name': 'Pittsburgh Steelers', 'price': 551.0},
#        {'name': 'Houston Texans', 'price': 1001.0}]}]},
#    {'key': 'pointsbetus',
#     'title': 'PointsBet (US)',
#     'last_update': '2022-10-26T16:43:22Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.9},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 7.5},
#        {'name': 'Tampa Bay Buccaneers', 'price': 15.0},
#        {'name': 'Minnesota Vikings', 'price': 16.0},
#        {'name': 'Baltimore Ravens', 'price': 17.0},
#        {'name': 'Dallas Cowboys', 'price': 18.0},
#        {'name': 'San Francisco 49ers', 'price': 18.0},
#        {'name': 'Cincinnati Bengals', 'price': 19.0},
#        {'name': 'Los Angeles Chargers', 'price': 26.0},
#        {'name': 'Los Angeles Rams', 'price': 26.0},
#        {'name': 'Green Bay Packers', 'price': 29.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Las Vegas Raiders', 'price': 51.0},
#        {'name': 'Tennessee Titans', 'price': 51.0},
#        {'name': 'Arizona Cardinals', 'price': 67.0},
#        {'name': 'Indianapolis Colts', 'price': 67.0},
#        {'name': 'Jacksonville Jaguars', 'price': 76.0},
#        {'name': 'New York Jets', 'price': 76.0},
#        {'name': 'New England Patriots', 'price': 81.0},
#        {'name': 'Cleveland Browns', 'price': 91.0},
#        {'name': 'New Orleans Saints', 'price': 101.0},
#        {'name': 'Seattle Seahawks', 'price': 101.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'Atlanta Falcons', 'price': 201.0},
#        {'name': 'Detroit Lions', 'price': 251.0},
#        {'name': 'Washington Commanders', 'price': 251.0},
#        {'name': 'Chicago Bears', 'price': 401.0},
#        {'name': 'Carolina Panthers', 'price': 501.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 1001.0}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2022-10-26T16:36:05Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.75},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 7.0},
#        {'name': 'San Francisco 49ers', 'price': 15.0},
#        {'name': 'Baltimore Ravens', 'price': 17.0},
#        {'name': 'Dallas Cowboys', 'price': 17.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Cincinnati Bengals', 'price': 21.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 21.0},
#        {'name': 'Los Angeles Rams', 'price': 26.0},
#        {'name': 'Green Bay Packers', 'price': 31.0},
#        {'name': 'Los Angeles Chargers', 'price': 31.0},
#        {'name': 'Miami Dolphins', 'price': 31.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Las Vegas Raiders', 'price': 51.0},
#        {'name': 'Tennessee Titans', 'price': 51.0},
#        {'name': 'New England Patriots', 'price': 67.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Indianapolis Colts', 'price': 81.0},
#        {'name': 'New York Jets', 'price': 81.0},
#        {'name': 'Cleveland Browns', 'price': 101.0},
#        {'name': 'Seattle Seahawks', 'price': 101.0},
#        {'name': 'Jacksonville Jaguars', 'price': 126.0},
#        {'name': 'New Orleans Saints', 'price': 126.0},
#        {'name': 'Denver Broncos', 'price': 151.0},
#        {'name': 'Atlanta Falcons', 'price': 201.0},
#        {'name': 'Detroit Lions', 'price': 301.0},
#        {'name': 'Carolina Panthers', 'price': 501.0},
#        {'name': 'Chicago Bears', 'price': 501.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 1001.0}]}]},
#    {'key': 'intertops',
#     'title': 'Intertops',
#     'last_update': '2022-10-26T16:38:32Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.75},
#        {'name': 'Philadelphia Eagles', 'price': 6.5},
#        {'name': 'Kansas City Chiefs', 'price': 7.0},
#        {'name': 'San Francisco 49ers', 'price': 17.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 17.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Dallas Cowboys', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 21.0},
#        {'name': 'Baltimore Ravens', 'price': 21.0},
#        {'name': 'Los Angeles Rams', 'price': 23.0},
#        {'name': 'Green Bay Packers', 'price': 29.0},
#        {'name': 'Los Angeles Chargers', 'price': 29.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'Tennessee Titans', 'price': 41.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'New England Patriots', 'price': 67.0},
#        {'name': 'Las Vegas Raiders', 'price': 67.0},
#        {'name': 'New York Jets', 'price': 67.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Indianapolis Colts', 'price': 81.0},
#        {'name': 'Denver Broncos', 'price': 101.0},
#        {'name': 'Cleveland Browns', 'price': 101.0},
#        {'name': 'Seattle Seahawks', 'price': 101.0},
#        {'name': 'Jacksonville Jaguars', 'price': 101.0},
#        {'name': 'New Orleans Saints', 'price': 126.0},
#        {'name': 'Atlanta Falcons', 'price': 151.0},
#        {'name': 'Washington Commanders', 'price': 251.0},
#        {'name': 'Carolina Panthers', 'price': 251.0},
#        {'name': 'Detroit Lions', 'price': 251.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Chicago Bears', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 1001.0}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2022-10-26T16:43:41Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.6},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 7.0},
#        {'name': 'San Francisco 49ers', 'price': 14.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Dallas Cowboys', 'price': 18.0},
#        {'name': 'Baltimore Ravens', 'price': 18.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 23.0},
#        {'name': 'Los Angeles Rams', 'price': 23.0},
#        {'name': 'Los Angeles Chargers', 'price': 29.0},
#        {'name': 'Green Bay Packers', 'price': 34.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Tennessee Titans', 'price': 46.0},
#        {'name': 'Las Vegas Raiders', 'price': 61.0},
#        {'name': 'New York Jets', 'price': 67.0},
#        {'name': 'New England Patriots', 'price': 76.0},
#        {'name': 'Indianapolis Colts', 'price': 76.0},
#        {'name': 'Seattle Seahawks', 'price': 81.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Atlanta Falcons', 'price': 101.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'New Orleans Saints', 'price': 126.0},
#        {'name': 'Jacksonville Jaguars', 'price': 126.0},
#        {'name': 'Cleveland Browns', 'price': 126.0},
#        {'name': 'Washington Commanders', 'price': 201.0},
#        {'name': 'Detroit Lions', 'price': 301.0},
#        {'name': 'Chicago Bears', 'price': 301.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Carolina Panthers', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 751.0}]}]},
#    {'key': 'sugarhouse',
#     'title': 'SugarHouse',
#     'last_update': '2022-10-26T16:43:42Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.6},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 7.0},
#        {'name': 'San Francisco 49ers', 'price': 14.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Baltimore Ravens', 'price': 18.0},
#        {'name': 'Dallas Cowboys', 'price': 18.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 23.0},
#        {'name': 'Los Angeles Rams', 'price': 23.0},
#        {'name': 'Los Angeles Chargers', 'price': 29.0},
#        {'name': 'Green Bay Packers', 'price': 34.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Tennessee Titans', 'price': 46.0},
#        {'name': 'Las Vegas Raiders', 'price': 61.0},
#        {'name': 'New York Jets', 'price': 67.0},
#        {'name': 'Indianapolis Colts', 'price': 76.0},
#        {'name': 'New England Patriots', 'price': 76.0},
#        {'name': 'Seattle Seahawks', 'price': 81.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Atlanta Falcons', 'price': 101.0},
#        {'name': 'Cleveland Browns', 'price': 126.0},
#        {'name': 'Jacksonville Jaguars', 'price': 126.0},
#        {'name': 'New Orleans Saints', 'price': 126.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'Washington Commanders', 'price': 201.0},
#        {'name': 'Detroit Lions', 'price': 301.0},
#        {'name': 'Chicago Bears', 'price': 301.0},
#        {'name': 'Carolina Panthers', 'price': 501.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 751.0}]}]},
#    {'key': 'barstool',
#     'title': 'Barstool Sportsbook',
#     'last_update': '2022-10-26T16:41:25Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.6},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 7.0},
#        {'name': 'San Francisco 49ers', 'price': 14.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Baltimore Ravens', 'price': 18.0},
#        {'name': 'Dallas Cowboys', 'price': 18.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 23.0},
#        {'name': 'Los Angeles Rams', 'price': 23.0},
#        {'name': 'Los Angeles Chargers', 'price': 29.0},
#        {'name': 'Green Bay Packers', 'price': 34.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Tennessee Titans', 'price': 46.0},
#        {'name': 'Las Vegas Raiders', 'price': 61.0},
#        {'name': 'New York Jets', 'price': 67.0},
#        {'name': 'Indianapolis Colts', 'price': 76.0},
#        {'name': 'New England Patriots', 'price': 76.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Seattle Seahawks', 'price': 81.0},
#        {'name': 'Atlanta Falcons', 'price': 101.0},
#        {'name': 'Cleveland Browns', 'price': 126.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'Jacksonville Jaguars', 'price': 126.0},
#        {'name': 'New Orleans Saints', 'price': 126.0},
#        {'name': 'Washington Commanders', 'price': 201.0},
#        {'name': 'Chicago Bears', 'price': 301.0},
#        {'name': 'Detroit Lions', 'price': 301.0},
#        {'name': 'Carolina Panthers', 'price': 501.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 751.0}]}]},
#    {'key': 'lowvig',
#     'title': 'LowVig.ag',
#     'last_update': '2022-10-26T16:40:38Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.75},
#        {'name': 'Philadelphia Eagles', 'price': 6.25},
#        {'name': 'Kansas City Chiefs', 'price': 8.0},
#        {'name': 'San Francisco 49ers', 'price': 15.0},
#        {'name': 'Baltimore Ravens', 'price': 17.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Dallas Cowboys', 'price': 19.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 23.0},
#        {'name': 'Los Angeles Rams', 'price': 26.0},
#        {'name': 'Los Angeles Chargers', 'price': 29.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'Green Bay Packers', 'price': 36.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Tennessee Titans', 'price': 46.0},
#        {'name': 'Las Vegas Raiders', 'price': 51.0},
#        {'name': 'New York Jets', 'price': 61.0},
#        {'name': 'New England Patriots', 'price': 76.0},
#        {'name': 'Seattle Seahawks', 'price': 76.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Indianapolis Colts', 'price': 81.0},
#        {'name': 'New Orleans Saints', 'price': 101.0},
#        {'name': 'Cleveland Browns', 'price': 126.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'Jacksonville Jaguars', 'price': 126.0},
#        {'name': 'Atlanta Falcons', 'price': 151.0},
#        {'name': 'Washington Commanders', 'price': 201.0},
#        {'name': 'Chicago Bears', 'price': 301.0},
#        {'name': 'Carolina Panthers', 'price': 401.0},
#        {'name': 'Detroit Lions', 'price': 401.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 1001.0}]}]},
#    {'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2022-10-26T16:31:52Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.75},
#        {'name': 'Philadelphia Eagles', 'price': 6.25},
#        {'name': 'Kansas City Chiefs', 'price': 8.0},
#        {'name': 'San Francisco 49ers', 'price': 15.0},
#        {'name': 'Baltimore Ravens', 'price': 17.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Dallas Cowboys', 'price': 19.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 23.0},
#        {'name': 'Los Angeles Rams', 'price': 26.0},
#        {'name': 'Los Angeles Chargers', 'price': 29.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'Green Bay Packers', 'price': 36.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Tennessee Titans', 'price': 46.0},
#        {'name': 'Las Vegas Raiders', 'price': 51.0},
#        {'name': 'New York Jets', 'price': 61.0},
#        {'name': 'New England Patriots', 'price': 76.0},
#        {'name': 'Seattle Seahawks', 'price': 76.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Indianapolis Colts', 'price': 81.0},
#        {'name': 'New Orleans Saints', 'price': 101.0},
#        {'name': 'Cleveland Browns', 'price': 126.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'Jacksonville Jaguars', 'price': 126.0},
#        {'name': 'Atlanta Falcons', 'price': 151.0},
#        {'name': 'Washington Commanders', 'price': 201.0},
#        {'name': 'Chicago Bears', 'price': 301.0},
#        {'name': 'Carolina Panthers', 'price': 401.0},
#        {'name': 'Detroit Lions', 'price': 401.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 1001.0}]}]},
#    {'key': 'foxbet',
#     'title': 'FOX Bet',
#     'last_update': '2022-10-26T16:40:00Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.5},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 7.5},
#        {'name': 'San Francisco 49ers', 'price': 15.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 17.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Baltimore Ravens', 'price': 17.0},
#        {'name': 'Dallas Cowboys', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 19.0},
#        {'name': 'Los Angeles Rams', 'price': 26.0},
#        {'name': 'Los Angeles Chargers', 'price': 31.0},
#        {'name': 'Green Bay Packers', 'price': 31.0},
#        {'name': 'Miami Dolphins', 'price': 36.0},
#        {'name': 'Tennessee Titans', 'price': 41.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'New England Patriots', 'price': 51.0},
#        {'name': 'Las Vegas Raiders', 'price': 61.0},
#        {'name': 'Indianapolis Colts', 'price': 81.0},
#        {'name': 'New York Jets', 'price': 81.0},
#        {'name': 'Arizona Cardinals', 'price': 91.0},
#        {'name': 'Seattle Seahawks', 'price': 101.0},
#        {'name': 'New Orleans Saints', 'price': 101.0},
#        {'name': 'Cleveland Browns', 'price': 101.0},
#        {'name': 'Jacksonville Jaguars', 'price': 101.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'Atlanta Falcons', 'price': 176.0},
#        {'name': 'Pittsburgh Steelers', 'price': 301.0},
#        {'name': 'Detroit Lions', 'price': 301.0},
#        {'name': 'Washington Commanders', 'price': 301.0},
#        {'name': 'Carolina Panthers', 'price': 401.0},
#        {'name': 'Houston Texans', 'price': 501.0},
#        {'name': 'Chicago Bears', 'price': 501.0}]}]},
#    {'key': 'mybookieag',
#     'title': 'MyBookie.ag',
#     'last_update': '2022-10-26T16:44:17Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.6},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 7.4},
#        {'name': 'San Francisco 49ers', 'price': 16.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 16.5},
#        {'name': 'Minnesota Vikings', 'price': 16.75},
#        {'name': 'Baltimore Ravens', 'price': 17.5},
#        {'name': 'Dallas Cowboys', 'price': 19.25},
#        {'name': 'Cincinnati Bengals', 'price': 22.0},
#        {'name': 'Los Angeles Rams', 'price': 24.0},
#        {'name': 'Los Angeles Chargers', 'price': 28.0},
#        {'name': 'Green Bay Packers', 'price': 30.0},
#        {'name': 'Miami Dolphins', 'price': 32.0},
#        {'name': 'New York Giants', 'price': 40.0},
#        {'name': 'Tennessee Titans', 'price': 42.0},
#        {'name': 'Las Vegas Raiders', 'price': 49.0},
#        {'name': 'New York Jets', 'price': 71.0},
#        {'name': 'Arizona Cardinals', 'price': 71.0},
#        {'name': 'New England Patriots', 'price': 76.0},
#        {'name': 'Indianapolis Colts', 'price': 91.0},
#        {'name': 'Seattle Seahawks', 'price': 96.0},
#        {'name': 'Jacksonville Jaguars', 'price': 101.0},
#        {'name': 'Cleveland Browns', 'price': 101.0},
#        {'name': 'Denver Broncos', 'price': 111.0},
#        {'name': 'New Orleans Saints', 'price': 131.0},
#        {'name': 'Atlanta Falcons', 'price': 151.0},
#        {'name': 'Washington Commanders', 'price': 201.0},
#        {'name': 'Detroit Lions', 'price': 281.0},
#        {'name': 'Carolina Panthers', 'price': 301.0},
#        {'name': 'Pittsburgh Steelers', 'price': 381.0},
#        {'name': 'Chicago Bears', 'price': 421.0},
#        {'name': 'Houston Texans', 'price': 951.0}]}]},
#    {'key': 'unibet_us',
#     'title': 'Unibet',
#     'last_update': '2022-10-26T16:44:07Z',
#     'markets': [{'key': 'outrights',
#       'outcomes': [{'name': 'Buffalo Bills', 'price': 3.6},
#        {'name': 'Philadelphia Eagles', 'price': 6.0},
#        {'name': 'Kansas City Chiefs', 'price': 7.0},
#        {'name': 'San Francisco 49ers', 'price': 14.0},
#        {'name': 'Minnesota Vikings', 'price': 17.0},
#        {'name': 'Baltimore Ravens', 'price': 18.0},
#        {'name': 'Dallas Cowboys', 'price': 18.0},
#        {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#        {'name': 'Cincinnati Bengals', 'price': 23.0},
#        {'name': 'Los Angeles Rams', 'price': 23.0},
#        {'name': 'Los Angeles Chargers', 'price': 29.0},
#        {'name': 'Green Bay Packers', 'price': 34.0},
#        {'name': 'Miami Dolphins', 'price': 34.0},
#        {'name': 'New York Giants', 'price': 41.0},
#        {'name': 'Tennessee Titans', 'price': 46.0},
#        {'name': 'Las Vegas Raiders', 'price': 61.0},
#        {'name': 'New York Jets', 'price': 67.0},
#        {'name': 'Indianapolis Colts', 'price': 76.0},
#        {'name': 'New England Patriots', 'price': 76.0},
#        {'name': 'Arizona Cardinals', 'price': 81.0},
#        {'name': 'Seattle Seahawks', 'price': 81.0},
#        {'name': 'Atlanta Falcons', 'price': 101.0},
#        {'name': 'Cleveland Browns', 'price': 126.0},
#        {'name': 'Denver Broncos', 'price': 126.0},
#        {'name': 'Jacksonville Jaguars', 'price': 126.0},
#        {'name': 'New Orleans Saints', 'price': 126.0},
#        {'name': 'Washington Commanders', 'price': 201.0},
#        {'name': 'Chicago Bears', 'price': 301.0},
#        {'name': 'Detroit Lions', 'price': 301.0},
#        {'name': 'Carolina Panthers', 'price': 501.0},
#        {'name': 'Pittsburgh Steelers', 'price': 501.0},
#        {'name': 'Houston Texans', 'price': 751.0}]}]}]}]

# %%
[i['key'] for i in result[0]['bookmakers']]
# Out:
# ['betfair',
#  'williamhill_us',
#  'circasports',
#  'fanduel',
#  'pointsbetus',
#  'betmgm',
#  'intertops',
#  'betrivers',
#  'sugarhouse',
#  'barstool',
#  'lowvig',
#  'betonlineag',
#  'foxbet',
#  'mybookieag',
#  'unibet_us']

# %%
books = result[0]['bookmakers']

# %%
ny_books = ['betrivers', 'betmgm', 'fanduel', 'williamhill_us', 'pointsbetus']
books = [i for i in result[0]['bookmakers'] if i['key'] in ny_books]
books
# Out:
# [{'key': 'williamhill_us',
#   'title': 'William Hill (US)',
#   'last_update': '2022-10-26T16:37:32Z',
#   'markets': [{'key': 'outrights',
#     'outcomes': [{'name': 'Buffalo Bills', 'price': 3.7},
#      {'name': 'Philadelphia Eagles', 'price': 6.0},
#      {'name': 'Kansas City Chiefs', 'price': 8.0},
#      {'name': 'San Francisco 49ers', 'price': 17.0},
#      {'name': 'Minnesota Vikings', 'price': 17.0},
#      {'name': 'Dallas Cowboys', 'price': 19.0},
#      {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#      {'name': 'Baltimore Ravens', 'price': 19.0},
#      {'name': 'Cincinnati Bengals', 'price': 23.0},
#      {'name': 'Los Angeles Chargers', 'price': 26.0},
#      {'name': 'Los Angeles Rams', 'price': 26.0},
#      {'name': 'Green Bay Packers', 'price': 29.0},
#      {'name': 'Miami Dolphins', 'price': 36.0},
#      {'name': 'Tennessee Titans', 'price': 41.0},
#      {'name': 'New York Giants', 'price': 41.0},
#      {'name': 'Las Vegas Raiders', 'price': 61.0},
#      {'name': 'New York Jets', 'price': 61.0},
#      {'name': 'New England Patriots', 'price': 81.0},
#      {'name': 'Arizona Cardinals', 'price': 81.0},
#      {'name': 'Seattle Seahawks', 'price': 101.0},
#      {'name': 'New Orleans Saints', 'price': 126.0},
#      {'name': 'Cleveland Browns', 'price': 126.0},
#      {'name': 'Denver Broncos', 'price': 126.0},
#      {'name': 'Jacksonville Jaguars', 'price': 126.0},
#      {'name': 'Indianapolis Colts', 'price': 126.0},
#      {'name': 'Atlanta Falcons', 'price': 151.0},
#      {'name': 'Washington Commanders', 'price': 201.0},
#      {'name': 'Pittsburgh Steelers', 'price': 301.0},
#      {'name': 'Chicago Bears', 'price': 401.0},
#      {'name': 'Carolina Panthers', 'price': 501.0},
#      {'name': 'Detroit Lions', 'price': 501.0},
#      {'name': 'Houston Texans', 'price': 1001.0}]}]},
#  {'key': 'fanduel',
#   'title': 'FanDuel',
#   'last_update': '2022-10-26T16:36:49Z',
#   'markets': [{'key': 'outrights',
#     'outcomes': [{'name': 'Buffalo Bills', 'price': 3.7},
#      {'name': 'Philadelphia Eagles', 'price': 6.5},
#      {'name': 'Kansas City Chiefs', 'price': 7.5},
#      {'name': 'San Francisco 49ers', 'price': 16.0},
#      {'name': 'Minnesota Vikings', 'price': 17.0},
#      {'name': 'Tampa Bay Buccaneers', 'price': 17.0},
#      {'name': 'Baltimore Ravens', 'price': 18.0},
#      {'name': 'Dallas Cowboys', 'price': 18.0},
#      {'name': 'Cincinnati Bengals', 'price': 22.0},
#      {'name': 'Los Angeles Rams', 'price': 25.0},
#      {'name': 'Los Angeles Chargers', 'price': 30.0},
#      {'name': 'Miami Dolphins', 'price': 34.0},
#      {'name': 'Green Bay Packers', 'price': 34.0},
#      {'name': 'New York Giants', 'price': 42.0},
#      {'name': 'Tennessee Titans', 'price': 48.0},
#      {'name': 'Las Vegas Raiders', 'price': 66.0},
#      {'name': 'Arizona Cardinals', 'price': 76.0},
#      {'name': 'New England Patriots', 'price': 76.0},
#      {'name': 'New York Jets', 'price': 76.0},
#      {'name': 'Cleveland Browns', 'price': 101.0},
#      {'name': 'New Orleans Saints', 'price': 101.0},
#      {'name': 'Seattle Seahawks', 'price': 101.0},
#      {'name': 'Indianapolis Colts', 'price': 101.0},
#      {'name': 'Jacksonville Jaguars', 'price': 111.0},
#      {'name': 'Denver Broncos', 'price': 121.0},
#      {'name': 'Atlanta Falcons', 'price': 171.0},
#      {'name': 'Washington Commanders', 'price': 211.0},
#      {'name': 'Chicago Bears', 'price': 251.0},
#      {'name': 'Detroit Lions', 'price': 261.0},
#      {'name': 'Carolina Panthers', 'price': 551.0},
#      {'name': 'Pittsburgh Steelers', 'price': 551.0},
#      {'name': 'Houston Texans', 'price': 1001.0}]}]},
#  {'key': 'pointsbetus',
#   'title': 'PointsBet (US)',
#   'last_update': '2022-10-26T16:43:22Z',
#   'markets': [{'key': 'outrights',
#     'outcomes': [{'name': 'Buffalo Bills', 'price': 3.9},
#      {'name': 'Philadelphia Eagles', 'price': 6.0},
#      {'name': 'Kansas City Chiefs', 'price': 7.5},
#      {'name': 'Tampa Bay Buccaneers', 'price': 15.0},
#      {'name': 'Minnesota Vikings', 'price': 16.0},
#      {'name': 'Baltimore Ravens', 'price': 17.0},
#      {'name': 'Dallas Cowboys', 'price': 18.0},
#      {'name': 'San Francisco 49ers', 'price': 18.0},
#      {'name': 'Cincinnati Bengals', 'price': 19.0},
#      {'name': 'Los Angeles Chargers', 'price': 26.0},
#      {'name': 'Los Angeles Rams', 'price': 26.0},
#      {'name': 'Green Bay Packers', 'price': 29.0},
#      {'name': 'Miami Dolphins', 'price': 34.0},
#      {'name': 'New York Giants', 'price': 41.0},
#      {'name': 'Las Vegas Raiders', 'price': 51.0},
#      {'name': 'Tennessee Titans', 'price': 51.0},
#      {'name': 'Arizona Cardinals', 'price': 67.0},
#      {'name': 'Indianapolis Colts', 'price': 67.0},
#      {'name': 'Jacksonville Jaguars', 'price': 76.0},
#      {'name': 'New York Jets', 'price': 76.0},
#      {'name': 'New England Patriots', 'price': 81.0},
#      {'name': 'Cleveland Browns', 'price': 91.0},
#      {'name': 'New Orleans Saints', 'price': 101.0},
#      {'name': 'Seattle Seahawks', 'price': 101.0},
#      {'name': 'Denver Broncos', 'price': 126.0},
#      {'name': 'Atlanta Falcons', 'price': 201.0},
#      {'name': 'Detroit Lions', 'price': 251.0},
#      {'name': 'Washington Commanders', 'price': 251.0},
#      {'name': 'Chicago Bears', 'price': 401.0},
#      {'name': 'Carolina Panthers', 'price': 501.0},
#      {'name': 'Pittsburgh Steelers', 'price': 501.0},
#      {'name': 'Houston Texans', 'price': 1001.0}]}]},
#  {'key': 'betmgm',
#   'title': 'BetMGM',
#   'last_update': '2022-10-26T16:36:05Z',
#   'markets': [{'key': 'outrights',
#     'outcomes': [{'name': 'Buffalo Bills', 'price': 3.75},
#      {'name': 'Philadelphia Eagles', 'price': 6.0},
#      {'name': 'Kansas City Chiefs', 'price': 7.0},
#      {'name': 'San Francisco 49ers', 'price': 15.0},
#      {'name': 'Baltimore Ravens', 'price': 17.0},
#      {'name': 'Dallas Cowboys', 'price': 17.0},
#      {'name': 'Minnesota Vikings', 'price': 17.0},
#      {'name': 'Cincinnati Bengals', 'price': 21.0},
#      {'name': 'Tampa Bay Buccaneers', 'price': 21.0},
#      {'name': 'Los Angeles Rams', 'price': 26.0},
#      {'name': 'Green Bay Packers', 'price': 31.0},
#      {'name': 'Los Angeles Chargers', 'price': 31.0},
#      {'name': 'Miami Dolphins', 'price': 31.0},
#      {'name': 'New York Giants', 'price': 41.0},
#      {'name': 'Las Vegas Raiders', 'price': 51.0},
#      {'name': 'Tennessee Titans', 'price': 51.0},
#      {'name': 'New England Patriots', 'price': 67.0},
#      {'name': 'Arizona Cardinals', 'price': 81.0},
#      {'name': 'Indianapolis Colts', 'price': 81.0},
#      {'name': 'New York Jets', 'price': 81.0},
#      {'name': 'Cleveland Browns', 'price': 101.0},
#      {'name': 'Seattle Seahawks', 'price': 101.0},
#      {'name': 'Jacksonville Jaguars', 'price': 126.0},
#      {'name': 'New Orleans Saints', 'price': 126.0},
#      {'name': 'Denver Broncos', 'price': 151.0},
#      {'name': 'Atlanta Falcons', 'price': 201.0},
#      {'name': 'Detroit Lions', 'price': 301.0},
#      {'name': 'Carolina Panthers', 'price': 501.0},
#      {'name': 'Chicago Bears', 'price': 501.0},
#      {'name': 'Pittsburgh Steelers', 'price': 501.0},
#      {'name': 'Houston Texans', 'price': 1001.0}]}]},
#  {'key': 'betrivers',
#   'title': 'BetRivers',
#   'last_update': '2022-10-26T16:43:41Z',
#   'markets': [{'key': 'outrights',
#     'outcomes': [{'name': 'Buffalo Bills', 'price': 3.6},
#      {'name': 'Philadelphia Eagles', 'price': 6.0},
#      {'name': 'Kansas City Chiefs', 'price': 7.0},
#      {'name': 'San Francisco 49ers', 'price': 14.0},
#      {'name': 'Minnesota Vikings', 'price': 17.0},
#      {'name': 'Dallas Cowboys', 'price': 18.0},
#      {'name': 'Baltimore Ravens', 'price': 18.0},
#      {'name': 'Tampa Bay Buccaneers', 'price': 19.0},
#      {'name': 'Cincinnati Bengals', 'price': 23.0},
#      {'name': 'Los Angeles Rams', 'price': 23.0},
#      {'name': 'Los Angeles Chargers', 'price': 29.0},
#      {'name': 'Green Bay Packers', 'price': 34.0},
#      {'name': 'Miami Dolphins', 'price': 34.0},
#      {'name': 'New York Giants', 'price': 41.0},
#      {'name': 'Tennessee Titans', 'price': 46.0},
#      {'name': 'Las Vegas Raiders', 'price': 61.0},
#      {'name': 'New York Jets', 'price': 67.0},
#      {'name': 'New England Patriots', 'price': 76.0},
#      {'name': 'Indianapolis Colts', 'price': 76.0},
#      {'name': 'Seattle Seahawks', 'price': 81.0},
#      {'name': 'Arizona Cardinals', 'price': 81.0},
#      {'name': 'Atlanta Falcons', 'price': 101.0},
#      {'name': 'Denver Broncos', 'price': 126.0},
#      {'name': 'New Orleans Saints', 'price': 126.0},
#      {'name': 'Jacksonville Jaguars', 'price': 126.0},
#      {'name': 'Cleveland Browns', 'price': 126.0},
#      {'name': 'Washington Commanders', 'price': 201.0},
#      {'name': 'Detroit Lions', 'price': 301.0},
#      {'name': 'Chicago Bears', 'price': 301.0},
#      {'name': 'Pittsburgh Steelers', 'price': 501.0},
#      {'name': 'Carolina Panthers', 'price': 501.0},
#      {'name': 'Houston Texans', 'price': 751.0}]}]}]

# %%
prices = pd.DataFrame([i for i in books[3]['markets'][0]['outcomes']])
prices.rename(columns={'price': books[3]['key']})
# Out:
#                     name   betmgm
# 0          Buffalo Bills     3.75
# 1    Philadelphia Eagles     6.00
# 2     Kansas City Chiefs     7.00
# 3    San Francisco 49ers    15.00
# 4       Baltimore Ravens    17.00
# 5         Dallas Cowboys    17.00
# 6      Minnesota Vikings    17.00
# 7     Cincinnati Bengals    21.00
# 8   Tampa Bay Buccaneers    21.00
# 9       Los Angeles Rams    26.00
# 10     Green Bay Packers    31.00
# 11  Los Angeles Chargers    31.00
# 12        Miami Dolphins    31.00
# 13       New York Giants    41.00
# 14     Las Vegas Raiders    51.00
# 15      Tennessee Titans    51.00
# 16  New England Patriots    67.00
# 17     Arizona Cardinals    81.00
# 18    Indianapolis Colts    81.00
# 19         New York Jets    81.00
# 20      Cleveland Browns   101.00
# 21      Seattle Seahawks   101.00
# 22  Jacksonville Jaguars   126.00
# 23    New Orleans Saints   126.00
# 24        Denver Broncos   151.00
# 25       Atlanta Falcons   201.00
# 26         Detroit Lions   301.00
# 27     Carolina Panthers   501.00
# 28         Chicago Bears   501.00
# 29   Pittsburgh Steelers   501.00
# 30        Houston Texans  1001.00

# %%
# Start by indexing by team
prices=fo

# Loop through books, join with original dataframe
for i in range(len(books)):
    df = pd.DataFrame(books[i]['markets'][0]['outcomes'])
    df = df.set_index(df['name'].map(team_dict))
    df = df.rename(columns={'price': books[i]['key']})

    prices = prices.join(df, how='outer').drop(columns='name')
    

prices = prices.dropna()

# %%
prices
# Out:
#      SB Win  williamhill_us  fanduel  pointsbetus  betmgm  betrivers
# ARI   0.001            81.0     76.0         67.0   81.00       81.0
# ATL   0.005           151.0    171.0        201.0  201.00      101.0
# BAL   0.066            19.0     18.0         17.0   17.00       18.0
# BUF   0.321             3.7      3.7          3.9    3.75        3.6
# CIN   0.033            23.0     22.0         19.0   21.00       23.0
# CLE   0.002           126.0    101.0         91.0  101.00      126.0
# DAL   0.081            19.0     18.0         18.0   17.00       18.0
# GB    0.008            29.0     34.0         29.0   31.00       34.0
# IND   0.001           126.0    101.0         67.0   81.00       76.0
# JAX   0.003           126.0    111.0         76.0  126.00      126.0
# KC    0.085             8.0      7.5          7.5    7.00        7.0
# LAC   0.014            26.0     30.0         26.0   31.00       29.0
# LAR   0.015            26.0     25.0         26.0   26.00       23.0
# LV    0.003            61.0     66.0         51.0   51.00       61.0
# MIA   0.011            36.0     34.0         34.0   31.00       34.0
# MIN   0.040            17.0     17.0         16.0   17.00       17.0
# NE    0.004            81.0     76.0         81.0   67.00       76.0
# NO    0.003           126.0    101.0        101.0  126.00      126.0
# NYG   0.009            41.0     42.0         41.0   41.00       41.0
# NYJ   0.013            61.0     76.0         76.0   81.00       67.0
# PHI   0.202             6.0      6.5          6.0    6.00        6.0
# PIT   0.001           301.0    551.0        501.0  501.00      501.0
# SEA   0.017           101.0    101.0        101.0  101.00       81.0
# SF    0.014            17.0     16.0         18.0   15.00       14.0
# TB    0.038            19.0     17.0         15.0   21.00       19.0
# TEN   0.008            41.0     48.0         51.0   51.00       46.0

# %%
prices['best_price'] = prices[[i for i in prices.columns if i in ny_books]].max(axis=1)

# %%
prices['beta'] = 1/prices['best_price']

# %%
prices['er'] = prices['SB Win'] * prices['best_price']

# %%
prices = prices.sort_values(by='er', ascending=False)

# %%
prices.iloc[0]
# Out:
# SB Win              0.017000
# williamhill_us    101.000000
# fanduel           101.000000
# pointsbetus       101.000000
# betmgm            101.000000
# betrivers          81.000000
# best_price        101.000000
# beta                0.009901
# er                  1.717000
# Name: SEA, dtype: float64

# %%
S = pd.DataFrame(columns=prices.columns)
not_S = prices
k = 0
rs = 1

# %%
# Algorithmically determine best choices
for k in range(0, len(prices)):
    if prices['er'].iloc[k] > rs:
        S = S.append(prices.loc[prices.index[k]])        
        not_S = not_S.drop(prices.index[k])
        rs = sum(not_S['SB Win']) / (1 - sum(S['beta']))
        print(f'Add {prices.index[k]} with er {prices["er"].iloc[k]} and new R(S): {rs}')
    else:
        break
# Out:
# Add SEA with er 1.717 and new R(S): 0.9908100000000001
# Add DAL with er 1.5390000000000001 and new R(S): 0.9600333518621458
# Add PHI with er 1.313 and new R(S): 0.890736405954269
# Add BAL with er 1.254 and new R(S): 0.8645812678218909
# Add BUF with er 1.2519 and new R(S): 0.6553170505096009
# Add NYJ with er 1.0530000000000002 and new R(S): 0.6446954420532764
# Add ATL with er 1.0050000000000001 and new R(S): 0.6407752099583371
# Add TB with er 0.7979999999999999 and new R(S): 0.6224984248693819
# Add CIN with er 0.759 and new R(S): 0.6062901292125737
# Add KC with er 0.68 and new R(S): 0.568084444025129
# Add MIN with er 0.68 and new R(S): 0.5319796540038096
# Add PIT with er 0.551 and new R(S): 0.5317884334956076

# %%
# Algorithmically determine allocations
if len(S) > 0:
    S['kelly_size'] = S['SB Win'] - S['beta'] * rs

# %%
B = 10000
S['bet_size'] = B * S['kelly_size']
cost = sum(S['bet_size'])
S['winnings'] = S['best_price'] * S['bet_size']
S['pnl'] = S['winnings'] - cost
S['ev'] = S['SB Win'] * S['pnl']

S
# Out:
#      SB Win  williamhill_us  fanduel  pointsbetus  betmgm  betrivers  \
# SEA   0.017           101.0    101.0        101.0  101.00       81.0
# DAL   0.081            19.0     18.0         18.0   17.00       18.0
# PHI   0.202             6.0      6.5          6.0    6.00        6.0
# BAL   0.066            19.0     18.0         17.0   17.00       18.0
# BUF   0.321             3.7      3.7          3.9    3.75        3.6
# NYJ   0.013            61.0     76.0         76.0   81.00       67.0
# ATL   0.005           151.0    171.0        201.0  201.00      101.0
# TB    0.038            19.0     17.0         15.0   21.00       19.0
# CIN   0.033            23.0     22.0         19.0   21.00       23.0
# KC    0.085             8.0      7.5          7.5    7.00        7.0
# MIN   0.040            17.0     17.0         16.0   17.00       17.0
# PIT   0.001           301.0    551.0        501.0  501.00      501.0
#
#      best_price      beta      er  kelly_size     bet_size      winnings  \
# SEA       101.0  0.009901  1.7170    0.011735   117.347680  11852.115665
# DAL        19.0  0.052632  1.5390    0.053011   530.111351  10072.115665
# PHI         6.5  0.153846  1.3130    0.120186  1201.863948   7812.115665
# BAL        19.0  0.052632  1.2540    0.038011   380.111351   7222.115665
# BUF         3.9  0.256410  1.2519    0.184644  1846.439914   7201.115665
# NYJ        81.0  0.012346  1.0530    0.006435    64.347107   5212.115665
# ATL       201.0  0.004975  1.0050    0.002354    23.542864   4732.115665
# TB         21.0  0.047619  0.7980    0.012677   126.767413   2662.115665
# CIN        23.0  0.043478  0.7590    0.009879    98.787638   2272.115665
# KC          8.0  0.125000  0.6800    0.018526   185.264458   1482.115665
# MIN        17.0  0.058824  0.6800    0.008718    87.183274   1482.115665
# PIT       551.0  0.001815  0.5510    0.000035     0.348667    192.115665
#
#         pnl       ev
# SEA  7190.0  122.230
# DAL  5410.0  438.210
# PHI  3150.0  636.300
# BAL  2560.0  168.960
# BUF  2539.0  815.019
# NYJ   550.0    7.150
# ATL    70.0    0.350
# TB  -2000.0  -76.000
# CIN -2390.0  -78.870
# KC  -3180.0 -270.300
# MIN -3180.0 -127.200
# PIT -4470.0   -4.470

# %%
sum(S['ev']) - cost*(1-sum(S['SB Win']))
# Out:
# 1174.4916648256965

# %%
# Out:
#       SB Win
# Team
# BUF    0.336
# PHI    0.208
# BAL    0.073
# TB     0.061
# DAL    0.055
# KC     0.041
# LAC    0.039
# SF     0.034
# MIN    0.033
# CIN    0.018
# LAR    0.013
# NE     0.012
# GB     0.011
# NYJ    0.008
# SEA    0.007
# ATL    0.007
# JAX    0.007
# MIA    0.006
# TEN    0.005
# NYG    0.004
# DEN    0.004
# NO     0.003
# CLE    0.003
# PIT    0.002
# LV     0.002
# IND    0.002
# HOU    0.001
